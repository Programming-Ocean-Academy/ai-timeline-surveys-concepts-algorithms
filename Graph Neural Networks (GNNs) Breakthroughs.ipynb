# %% [markdown]
# # 📜 Graph Neural Networks (GNNs) Breakthroughs
#
# ---
#
# ## 📚 Key Milestones
#
# | **Era** | **Model / Concept** | **Year** | **Authors / Org** | **Key Contributions** |
# |---------|----------------------|----------|-------------------|-----------------------|
# | **Early Foundations** | **Neural Networks for Graphs** | 2005 | Gori et al. | First NN architecture directly designed for graph-structured data. |
# | | **Graph Neural Network (formalization)** | 2009 | Scarselli et al. | General GNN framework via message passing; laid theoretical groundwork. |
# | **Core Architectures** | **GCN (Graph Convolutional Network)** | 2016 | Kipf & Welling | Scalable convolution on graphs; became standard GNN baseline. |
# | | **GraphSAGE** | 2017 | Hamilton et al. (Stanford) | Inductive representation learning with neighborhood sampling on large-scale graphs. |
# | **Variants & Improvements** | **GAT (Graph Attention Networks)** | 2018 | Veličković et al. (DeepMind) | Introduced attention for message passing, improving expressiveness. |
# | | **GIN (Graph Isomorphism Network)** | 2019 | Xu et al. | Showed GNNs can match the power of the Weisfeiler–Lehman graph isomorphism test. |
# | | **Graph Transformers** | 2020–2021 | Dwivedi & Bresson; Ying et al. (Microsoft Graphormer) | Combined Transformers with GNNs for long-range dependencies and large graphs. |
# | **Applications** | **Social Networks** | 2010s–2020s | Facebook, Twitter | Community detection, recommendations. |
# | | **Molecular Graphs** | 2010s–2020s | DeepChem, AlphaFold pipelines | Drug discovery, protein folding. |
# | | **Knowledge Graphs** | 2010s–2020s | Google, industrial systems | Link prediction, entity classification. |
# | | **Traffic & Sensor Networks** | 2020s | Various research & industry | Spatio-temporal GNNs for flow forecasting. |
#
# ---
#
# ## ✅ Summary Families
# - **Foundations:** Gori (2005), Scarselli (2009).
# - **Core GNNs:** GCN (2016), GraphSAGE (2017).
# - **Variants:** GAT (2018), GIN (2019), Graph Transformers (2020+).
# - **Applications:** Social networks, molecular discovery, knowledge graphs, spatio-temporal forecasting.
