# %% [markdown]
# # Deep Unsupervised Learning using Nonequilibrium Thermodynamics
# ## Complete Paper Table (Origin + Prior + Derivative Works)
#
# | Paper Title                                                    | Authors                                                                                                                                             | Year | Category          |
# | -------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------- | ---- | ----------------- |
# | Deep Unsupervised Learning using Nonequilibrium Thermodynamics | Jascha N. Sohl-Dickstein, Eric A. Weiss, Niru Maheswaranathan, S. Ganguli                                                                           | 2015 | Origin Paper      |
# | Diffusion Models Beat GANs on Image Synthesis                  | Prafulla Dhariwal, Alex Nichol                                                                                                                      | 2021 | Derivative        |
# | Denoising Diffusion Implicit Models                            | Jiaming Song, Chenlin Meng, Stefano Ermon                                                                                                           | 2020 | Derivative        |
# | Improved Denoising Diffusion Probabilistic Models              | Alex Nichol, Prafulla Dhariwal                                                                                                                      | 2021 | Derivative        |
# | Hierarchical Text-Conditional Image Generation with CLIP Latents | A. Ramesh, Prafulla Dhariwal, Alex Nichol, Casey Chu, Mark Chen                                                                                    | 2022 | Derivative        |
# | GLIDE: Text-Guided Photorealistic Image Generation & Editing   | Alex Nichol, Prafulla Dhariwal, A. Ramesh, Pranav Shyam, Pamela Mishkin, Bob McGrew, I. Sutskever, Mark Chen                                       | 2021 | Derivative        |
# | Cascaded Diffusion Models                                      | Jonathan Ho, Chitwan Saharia, William Chan, David Fleet, Mohammad Norouzi, Tim Salimans                                                            | 2021 | Derivative        |
# | Scalable Diffusion Models with Transformers                    | William S. Peebles, Saining Xie                                                                                                                     | 2022 | Derivative        |
# | Elucidating the Design Space of Diffusion Models               | Tero Karras, M. Aittala, Timo Aila, S. Laine                                                                                                        | 2022 | Derivative        |
# | Image Super-Resolution via Iterative Refinement                | Chitwan Saharia, Jonathan Ho, William Chan, Tim Salimans, David Fleet, Mohammad Norouzi                                                             | 2021 | Derivative        |
# | GANs Trained by Two-Time-Scale Update Rule (TTUR)              | M. Heusel, H. Ramsauer, T. Unterthiner, B. Nessler, S. Hochreiter                                                                                   | 2017 | Related Prior     |
# | Blended Diffusion                                              | Omri Avrahami, D. Lischinski, Ohad Fried                                                                                                            | 2021 | Derivative        |
# | Textual Inversion                                              | Rinon Gal, Yuval Alaluf, Y. Atzmon, O. Patashnik, A. Bermano, G. Chechik, D. Cohen-Or                                                               | 2022 | Derivative        |
# | Large-Scale GAN Training (BigGAN)                              | Andrew Brock, Jeff Donahue, K. Simonyan                                                                                                             | 2018 | Related           |
# | Auto-Encoding Variational Bayes (VAE)                          | Romain Lopez, Pierre Boyeau, N. Yosef, Michael I. Jordan, J. Regier                                                                                 | 2020 | Related           |
# | DiffWave                                                       | Zhifeng Kong, Wei Ping, Jiaji Huang, Kexin Zhao, Bryan Catanzaro                                                                                    | 2020 | Derivative        |
# | SDEdit                                                         | Chenlin Meng, Yutong He, Yang Song, Jiaming Song, Jiajun Wu, Jun-Yan Zhu, Stefano Ermon                                                             | 2021 | Derivative        |
# | Maximum Likelihood Training of Score-Based Diffusion Models    | Yang Song, Conor Durkan, Iain Murray, Stefano Ermon                                                                                                 | 2021 | Derivative        |
# | Palette                                                        | Chitwan Saharia, William Chan, Huiwen Chang, Chris A. Lee, Jonathan Ho, Tim Salimans, David Fleet, Mohammad Norouzi                                 | 2021 | Derivative        |
# | Score-Based Generative Modeling in Latent Space                | Arash Vahdat, Karsten Kreis, Jan Kautz                                                                                                              | 2021 | Derivative        |
# | Improved Techniques for Training Score-Based Models            | Yang Song, Stefano Ermon                                                                                                                            | 2020 | Derivative        |
# | VQ-Diffusion                                                   | Shuyang Gu, Dong Chen, Jianmin Bao, Fang Wen, Bo Zhang, Dongdong Chen, Lu Yuan, B. Guo                                                              | 2021 | Derivative        |
# | DiffuseVAE                                                     | Kushagra Pandey, Avideep Mukherjee, Piyush Rai, Abhishek Kumar                                                                                      | 2022 | Derivative        |
# | Imagic                                                         | Bahjat Kawar, Shiran Zada, Oran Lang, Omer Tov, Hui-Tang Chang, Tali Dekel, Inbar Mosseri, M. Irani                                                 | 2022 | Derivative        |
# | RePaint                                                        | Andreas Lugmayr, Martin Danelljan, Andrés Romero, F. Yu, R. Timofte, L. Van Gool                                                                     | 2022 | Derivative        |
# | Scaling Autoregressive Models for Rich T2I                     | Jiahui Yu et al.                                                                                                                                     | 2022 | Related           |
# | Entropy-Driven Sampling for Conditional Diffusion              | Sheng-liang Li et al.                                                                                                                               | 2022 | Derivative        |
# | Make-A-Scene                                                   | Oran Gafni et al.                                                                                                                                   | 2022 | Derivative        |
# | StyleGAN                                                       | Tero Karras, S. Laine, Timo Aila                                                                                                                    | 2018 | Related           |
# | Analog Bits                                                    | Ting Chen, Ruixiang Zhang, Geoffrey Hinton                                                                                                          | 2022 | Derivative        |
# | DiffusionCLIP                                                  | Gwanghyun Kim, Taesung Kwon, Jong-Chul Ye                                                                                                           | 2021 | Derivative        |
# | LAION-5B Dataset                                               | Christoph Schuhmann et al.                                                                                                                          | 2022 | Related           |
# | Scaling Rectified Flow Transformers                            | Patrick Esser et al.                                                                                                                                | 2024 | Derivative        |
# | Conditioning with Gaussian Mixture Model                       | Weiguo Lu et al.                                                                                                                                    | 2024 | Derivative        |
# | S2-DMs: Skip-Step Diffusion Models                             | Yixuan Wang, Shuangyin Li                                                                                                                           | 2024 | Derivative        |
# | Pseudo Numerical Methods for Diffusion on Manifolds            | Luping Liu, Yi Ren, Zhijie Lin, Zhou Zhao                                                                                                           | 2022 | Derivative        |
# | eDiff-I                                                        | Y. Balaji et al.                                                                                                                                    | 2022 | Derivative        |
# | Imagen Video                                                   | Jonathan Ho, William Chan, Chitwan Saharia, Jay Whang, Ruiqi Gao, A. Gritsenko, Diederik Kingma, Ben Poole, Mohammad Norouzi, David Fleet, Tim Salimans | 2022 | Derivative        |
# | Learning Transferable Visual Models (CLIP)                     | Alec Radford et al.                                                                                                                                 | 2021 | Related           |
# | ImageBART                                                      | Patrick Esser, Robin Rombach, A. Blattmann, B. Ommer                                                                                                | 2021 | Derivative        |
# | On Fast Sampling of Diffusion Models                           | Zhifeng Kong, Wei Ping                                                                                                                              | 2021 | Derivative        |

# %% [markdown]
# ## Denoising Diffusion Probabilistic Models — Full Paper Table
#
# | Paper Title                                                              | Authors                                                          | Year | Category         |
# | ------------------------------------------------------------------------ | ---------------------------------------------------------------- | ---- | ----------------- |
# | Denoising Diffusion Probabilistic Models                                 | Jonathan Ho, Ajay Jain, P. Abbeel                                | 2020 | Origin Paper     |
# | Denoising Diffusion Implicit Models                                      | Jiaming Song, Chenlin Meng, Stefano Ermon                        | 2020 | Derivative        |
# | High-Resolution Image Synthesis with Latent Diffusion Models             | Robin Rombach, A. Blattmann, Dominik Lorenz, Patrick Esser, B. Ommer | 2021 | Derivative        |
# | Score-Based Generative Modeling through Stochastic Differential Equations | Yang Song et al.                                                 | 2020 | Prior / Related   |
# | Deep Unsupervised Learning using Nonequilibrium Thermodynamics           | Jascha N. Sohl-Dickstein et al.                                  | 2015 | Prior             |
# | Improved Denoising Diffusion Probabilistic Models                        | Alex Nichol, Prafulla Dhariwal                                   | 2021 | Derivative        |
# | Generative Modeling by Estimating Gradients of the Data Distribution     | Yang Song, Stefano Ermon                                         | 2019 | Prior             |
# | Photorealistic Text-to-Image Diffusion Models                            | Chitwan Saharia et al.                                           | 2022 | Derivative        |
# | Classifier-Free Diffusion Guidance                                       | Jonathan Ho                                                      | 2022 | Derivative        |
# | GANs Trained by a Two Time-Scale Update Rule (TTUR)                      | M. Heusel et al.                                                 | 2017 | Related           |
# | Learning Transferable Visual Models From Natural Language Supervision (CLIP) | Alec Radford et al.                                          | 2021 | Related           |
# | Structured Denoising Diffusion Models in Discrete State-Spaces           | Jacob Austin et al.                                              | 2021 | Derivative        |
# | Scalable Diffusion Models with Transformers                              | William Peebles, Saining Xie                                     | 2022 | Derivative        |
# | Image Super-Resolution via Iterative Refinement                          | Chitwan Saharia et al.                                           | 2021 | Derivative        |
# | Retrieval-Augmented Diffusion Models                                     | A. Blattmann, Robin Rombach, K. Oktay, B. Ommer                  | 2022 | Derivative        |
# | SDXL: Improving Latent Diffusion Models                                  | Dustin Podell et al.                                             | 2023 | Derivative        |
# | Zero-Shot Text-to-Image Generation (DALL·E 1)                            | A. Ramesh et al.                                                 | 2021 | Prior / Related   |
# | Variational Diffusion Models                                             | Diederik P. Kingma, Tim Salimans, Ben Poole, Jonathan Ho         | 2021 | Derivative        |
# | Improved Techniques for Training Score-Based Generative Models           | Yang Song, Stefano Ermon                                         | 2020 | Derivative        |
# | A Style-Based Generator Architecture for GANs (StyleGAN)                 | Tero Karras, S. Laine, Timo Aila                                 | 2018 | Related           |
# | Maximum Likelihood Training of Score-Based Diffusion Models              | Yang Song, Conor Durkan, Iain Murray, Stefano Ermon              | 2021 | Derivative        |
# | A Connection Between Score Matching and Denoising Autoencoders           | Pascal Vincent                                                   | 2011 | Prior             |
# | Scaling Autoregressive Models for Rich Text-to-Image Generation          | Jiahui Yu et al.                                                 | 2022 | Related           |
# | DiffWave: A Versatile Diffusion Model for Audio                          | Zhifeng Kong et al.                                              | 2020 | Derivative        |
# | Frido: Feature Pyramid Diffusion                                         | Wanshu Fan et al.                                                | 2022 | Derivative        |
# | Cooperative Learning of Langevin & Normalizing Flow                      | Jianwen Xie et al.                                               | 2022 | Related           |
# | Unreasonable Effectiveness of Deep Features as Perceptual Metric (LPIPS) | Richard Zhang et al.                                             | 2018 | Related           |
# | Neural Discrete Representation Learning (VQ-VAE)                         | Aäron van den Oord et al.                                        | 2017 | Prior             |
# | VideoGPT                                                                 | Wilson Yan et al.                                                | 2021 | Related           |
# | Flow Straight and Fast (Rectified Flow)                                  | Xingchao Liu et al.                                              | 2022 | Derivative        |
# | InstructPix2Pix                                                          | Tim Brooks, Aleksander Holynski, Alexei A. Efros                 | 2022 | Derivative        |
# | DiVAE: Photorealistic Image Synthesis with Diffusion Decoder             | Jie Shi et al.                                                   | 2022 | Derivative        |
# | VQ-VAE-2: Diverse High-Fidelity Images                                   | Ali Razavi et al.                                                | 2019 | Related           |
# | Analyzing & Improving StyleGAN                                           | Tero Karras et al.                                               | 2019 | Related           |
# | PixelPyramids                                                            | Shweta Mahajan, S. Roth                                          | 2021 | Related           |
# | Multi-Concept Customization of Text-to-Image Diffusion                   | Nupur Kumari et al.                                              | 2022 | Derivative        |
# | Diffusion-LM: Controllable Text Generation                               | Xiang Lisa Li et al.                                             | 2022 | Derivative        |
# | Scaling Rectified Flow Transformers                                      | Patrick Esser et al.                                             | 2024 | Derivative        |
# | Deep Generative Modelling: Comparative Review                            | Sam Bond-Taylor et al.                                           | 2021 | Related           |
# | Progressive Growing of GANs                                              | Tero Karras et al.                                               | 2017 | Related           |
# | Analog Bits: Discrete Diffusion with Self-Conditioning                   | Ting Chen, Ruixiang Zhang, Geoffrey Hinton                       | 2022 | Derivative        |

# %% [markdown]
# ## Score-Based & Diffusion Model Papers — Full Table
#
# | Paper Title                                                                          | Authors                                                                                                   | Year                                  | Category               |
# | ------------------------------------------------------------------------------------ | --------------------------------------------------------------------------------------------------------- | ------------------------------------- | ---------------------- |
# | Score-Based Generative Modeling through Stochastic Differential Equations            | Yang Song, Jascha N. Sohl-Dickstein, Diederik P. Kingma, Abhishek Kumar, Stefano Ermon, Ben Poole         | 2020                                  | Origin Paper           |
# | Denoising Diffusion Probabilistic Models                                             | Jonathan Ho, Ajay Jain, P. Abbeel                                                                         | 2020                                  | Prior / Foundational   |
# | Generative Modeling by Estimating Gradients of the Data Distribution                 | Yang Song, Stefano Ermon                                                                                  | 2019                                  | Prior                  |
# | Diffusion Models Beat GANs on Image Synthesis                                        | Prafulla Dhariwal, Alex Nichol                                                                            | 2021                                  | Derivative             |
# | Deep Unsupervised Learning using Nonequilibrium Thermodynamics                       | Jascha N. Sohl-Dickstein, Eric A. Weiss, Niru Maheswaranathan, S. Ganguli                                 | 2015                                  | Prior                  |
# | Elucidating the Design Space of Diffusion-Based Generative Models                    | Tero Karras, M. Aittala, Timo Aila, S. Laine                                                              | 2022                                  | Derivative             |
# | Improved Denoising Diffusion Probabilistic Models                                    | Alex Nichol, Prafulla Dhariwal                                                                            | 2021                                  | Derivative             |
# | High-Resolution Image Synthesis with Latent Diffusion Models                         | Robin Rombach, A. Blattmann, Dominik Lorenz, Patrick Esser, B. Ommer                                      | 2021                                  | Derivative             |
# | Classifier-Free Diffusion Guidance                                                   | Jonathan Ho                                                                                               | 2022                                  | Derivative             |
# | GLIDE: Photorealistic Image Generation & Editing with Text Guidance                  | Alex Nichol, Prafulla Dhariwal, A. Ramesh, Pranav Shyam, Pamela Mishkin, Bob McGrew, I. Sutskever, Mark Chen | 2021                              | Derivative             |
# | Consistency Models                                                                   | Yang Song, Prafulla Dhariwal, Mark Chen, I. Sutskever                                                     | 2023                                  | Derivative             |
# | Maximum Likelihood Training of Score-Based Diffusion Models                          | Yang Song, Conor Durkan, Iain Murray, Stefano Ermon                                                       | 2021                                  | Derivative             |
# | Hierarchical Text-Conditional Image Generation with CLIP Latents                     | A. Ramesh, Prafulla Dhariwal, Alex Nichol, Casey Chu, Mark Chen                                           | 2022                                  | Derivative             |
# | Improved Techniques for Training Score-Based Generative Models                       | Yang Song, Stefano Ermon                                                                                  | 2020                                  | Derivative             |
# | Photorealistic Text-to-Image Diffusion Models with Deep Language Understanding       | Chitwan Saharia et al.                                                                                    | 2022                                  | Derivative             |
# | A Connection Between Score Matching and Denoising Autoencoders                       | Pascal Vincent                                                                                            | 2011                                  | Prior                  |
# | Score-Based Generative Modeling in Latent Space                                      | Arash Vahdat, Karsten Kreis, Jan Kautz                                                                    | 2021                                  | Derivative             |
# | GANs Trained by a Two Time-Scale Update Rule Converge to a Local Nash Equilibrium (TTUR) | M. Heusel, Hubert Ramsauer, Thomas Unterthiner, B. Nessler, S. Hochreiter                             | 2017                                  | Related Prior          |
# | Maximum Likelihood Training of Score-Based Diffusion Models (Edinburgh Explorer)     | Yang Song, Conor Durkan, Iain Murray, Stefano Ermon                                                       | —                                     | Duplicate Entry        |
# | Flow Straight and Fast: Rectified Flow                                               | Xingchao Liu, Chengyue Gong, Qiang Liu                                                                    | 2022                                  | Derivative             |
# | DPM-Solver++: Fast ODE Solver                                                        | Cheng Lu, Yuhao Zhou, Fan Bao, Jianfei Chen, Chongxuan Li, Jun Zhu                                        | 2022                                  | Derivative             |
# | Taming Transformers for High-Resolution Image Synthesis                              | Patrick Esser, Robin Rombach, B. Ommer                                                                    | 2020                                  | Prior / Related        |
# | SDEdit: Guided Image Synthesis & Editing                                             | Chenlin Meng, Yutong He, Yang Song, Jiaming Song, Jiajun Wu, Jun-Yan Zhu, Stefano Ermon                   | 2021                                  | Derivative             |
# | DiffWave: A Versatile Diffusion Model for Audio                                      | Zhifeng Kong, Wei Ping, Jiaji Huang, Kexin Zhao, Bryan Catanzaro                                          | 2020                                  | Derivative             |
# | Improved Techniques for Training Consistency Models                                  | Yang Song, Prafulla Dhariwal                                                                              | 2023                                  | Derivative             |
# | GENIE: Higher-Order Denoising Diffusion Solvers                                      | Tim Dockhorn, Arash Vahdat, Karsten Kreis                                                                 | 2022                                  | Derivative             |
# | One-Step Diffusion with Distribution Matching Distillation                           | Tianwei Yin, Michael Gharbi, Richard Zhang, Eli Shechtman, Frédo Durand, W. T. Freeman, Taesung Park      | 2023                                  | Derivative             |
# | Reverse-Time Diffusion Equation Models                                               | B. Anderson                                                                                               | 1982                                  | Prior / Classical      |
# | Score-Based Diffusion Models for Accelerated MRI                                     | Hyungjin Chung, Jong-Chul Ye                                                                              | 2021                                  | Application            |
# | Estimation of Non-Normalized Statistical Models by Score Matching                    | Aapo Hyvärinen                                                                                            | 2005                                  | Prior                  |
# | Diffusion Posterior Sampling for Noisy Inverse Problems                              | Hyungjin Chung, Jeongsol Kim, Michael T. McCann, M. Klasky, J. C. Ye                                      | 2022                                  | Application            |
# | gDDIM: Generalized DDIM                                                              | Qinsheng Zhang, Molei Tao, Yongxin Chen                                                                   | 2022                                  | Derivative             |
# | Align Your Latents: High-Resolution Video Synthesis                                  | A. Blattmann, Robin Rombach, Huan Ling, Tim Dockhorn, Seung Wook Kim, S. Fidler, Karsten Kreis            | 2023                                  | Derivative             |
# | Video Diffusion Models                                                               | Jonathan Ho, Tim Salimans, Alexey Gritsenko, William Chan, Mohammad Norouzi, David J. Fleet               | 2022                                  | Derivative             |
# | Prompt-to-Prompt Image Editing with Cross Attention Control                          | Amir Hertz, Ron Mokady, J. Tenenbaum, Kfir Aberman, Y. Pritch, D. Cohen-Or                                | 2022                                  | Derivative             |
# | Decision-Making with Auto-Encoding Variational Bayes                                 | Romain Lopez, Pierre Boyeau, N. Yosef, Michael I. Jordan, J. Regier                                       | 2020                                  | Related                |
# | ILVR: Conditioning Method for DDPM                                                   | Jooyoung Choi, Sungwon Kim, Yonghyun Jeong, Youngjune Gwon, Sungroh Yoon                                  | 2021                                  | Derivative             |
# | Pseudo Numerical Methods for Diffusion Models on Manifolds                           | Luping Liu, Yi Ren, Zhijie Lin, Zhou Zhao                                                                 | 2022                                  | Derivative             |
# | Latent Consistency Models                                                            | Simian Luo, Yiqin Tan, Longbo Huang, Jian Li, Hang Zhao                                                   | 2023                                  | Derivative             |
# | StyleGAN: A Style-Based Generator Architecture                                       | Tero Karras, S. Laine, Timo Aila                                                                          | 2018                                  | Prior / Related GAN    |
# | VAEBM: Symbiosis of VAEs & EBMs                                                      | Zhisheng Xiao, Karsten Kreis, Jan Kautz, Arash Vahdat                                                     | 2020                                  | Related                |
# | —                                                                                    | —                                                                                                         | Sponsored timeline references (1982–2023) | —                    |
