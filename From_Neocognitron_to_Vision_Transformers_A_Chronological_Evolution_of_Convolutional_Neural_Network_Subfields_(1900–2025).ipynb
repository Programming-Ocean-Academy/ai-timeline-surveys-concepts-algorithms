# %% [markdown]
# # 📖 Chronological Evolution of CNN Subfields (1900–2025)
#
# ---
#
# ## 1. 🧠 Biological & Mathematical Foundations (1900–1970s)
#
# - 1909 – David Hubel (born; later Nobel Prize in Medicine for visual cortex studies).
# - 1943 – McCulloch & Pitts: artificial neurons → conceptual basis.
# - 1959 – Hubel & Wiesel (Nobel-winning research): discovery of receptive fields in the cat visual cortex → direct inspiration for convolution filters.
# - 1962 – Widrow & Hoff: adaptive linear neurons (ADALINE).
# - 1969 – Minsky & Papert’s *Perceptrons*: critique stalls NN research until backprop is rediscovered.
#
# ---
#
# ## 2. 🖼️ Early CNN Concepts & Digit Recognition (1980s–1990s)
#
# - 1980 – Fukushima: **Neocognitron** (first CNN-like model, inspired by visual cortex).
# - 1986 – Rumelhart et al.: backpropagation popularized.
# - 1989 – Yann LeCun applies CNNs + backprop to handwritten digit recognition.
# - 1998 – LeCun’s **LeNet-5**: convolution + subsampling layers for MNIST OCR → seminal CNN architecture.
#
# ---
#
# ## 3. 🏢 CNNs in Computer Vision Subfields (2000s–2011)
#
# - 2000s – CNNs explored in:
#   - Face recognition (Rowley et al.).
#   - Traffic sign recognition (early benchmarks).
#   - Medical imaging (early CT/MRI pattern detection).
# - **Barriers**: limited data + computational cost. CNNs overshadowed by SVMs + handcrafted features (HOG, SIFT).
#
# ---
#
# ## 4. 🚀 Deep CNN Breakthrough (2012–2014)
#
# - 2012 – **AlexNet** (Krizhevsky, Sutskever, Hinton): ImageNet classification with GPU training → 10× error reduction.
# - 2013 – Zeiler & Fergus visualize CNN filters.
# - 2014 – **VGGNet** (Simonyan & Zisserman): deep CNNs (16–19 layers).
# - 2014 – **GoogLeNet/Inception** (Szegedy et al.): factorized convolutions, network-in-network.
#
# ---
#
# ## 5. 🏛️ CNN Subfields in Vision Architectures (2015–2016)
#
# - 2015 – **ResNet** (He et al.): residual connections solve vanishing gradient → extremely deep CNNs (152+ layers).
# - 2015 – **FractalNet**: explores depth vs width scaling.
# - 2015 – **Fully Convolutional Networks (FCN)** for semantic segmentation (Long et al.).
# - 2016 – **DenseNet** (Huang et al.): dense connectivity pattern.
#
# ---
#
# ## 6. 📊 CNN Subfields in Specific Applications (2015–2020)
#
# **Detection**:
# - R-CNN (2014), Fast R-CNN (2015), Faster R-CNN (2015).
# - **YOLO** (Redmon et al., 2016): real-time object detection.
# - **SSD** (2016): efficient detection.
#
# **Segmentation**:
# - **U-Net** (2015): medical imaging.
# - **Mask R-CNN** (2017): instance segmentation.
#
# **Generative Modeling**:
# - **DCGAN** (2015): CNNs for adversarial image generation.
#
# **Super-Resolution**:
# - **SRCNN** (Dong et al., 2014).
#
# **Video**:
# - **C3D** (2014): 3D convolutions for spatiotemporal modeling.
#
# ---
#
# ## 7. 🧩 CNN Hybrid Subfields (2017–2020)
#
# - **Capsule Networks (CapsNets)** (Sabour et al., 2017): attempt to fix CNN’s spatial hierarchy issues.
#
# **Attention + CNN Hybrids**:
# - Squeeze-and-Excitation Networks (2017).
# - Non-local Neural Networks (2018).
#
# **Efficient Architectures**:
# - **MobileNet** (2017).
# - **ShuffleNet** (2018).
# - **EfficientNet** (Tan & Le, 2019): scaling laws for CNNs.
#
# ---
#
# ## 8. ⚡ CNN vs Transformers (2020–2025)
#
# - 2020 – **Vision Transformer (ViT)**: CNNs challenged by pure self-attention.
# - 2021–2022 – Hybrid CNN+Transformer models: **ConvNeXt, CoAtNet**.
# - 2023–2025 – CNNs survive in efficiency-critical tasks:
#   - Real-time mobile inference.
#   - Low-power edge devices.
#   - Dense prediction tasks where inductive bias (translation equivariance) still helps.
#
# ---
#
# ## 9. 🏥 CNNs in Applied Subfields (2000–2025)
#
# - **Medical Imaging**: U-Net, 3D CNNs, CNN-RNN hybrids in radiology, pathology, genomics.
# - **Autonomous Driving**: CNN-based perception pipelines (lane detection, obstacle detection).
# - **Remote Sensing**: CNNs for satellite image analysis.
# - **Video & Action Recognition**: SlowFast Networks (2019).
# - **Art & Creativity**: CNNs in style transfer (Gatys et al., 2015).
#
# ---
#
# ## 📑 Conclusion
#
# The chronological evolution of CNN subfields shows a trajectory from:
#
# **Biological inspiration (1950s–1980s) → digit recognition (1990s) → ImageNet revolution (2012) → architectural innovations (2014–2019) → application-specific CNNs (detection, segmentation, super-resolution, video) → hybrids and Transformer competition (2020s).**
#
# Today (2025), CNNs are no longer the dominant universal paradigm but remain crucial in **efficiency-driven, structure-sensitive, and application-specific domains**.
